# %% [markdown]
# # Feature Inspection
#
# The complete set of extracted features, found in "extracted_features.csv", includes about 400 features, most of them highly redundant. Pruning them down to a manageable amount was done by first manually inspecting their behavior for different classes, then testing different groups of them through trial and error in ML models. In this notebook, we describe some of the manual inspecting we did for some features. The next notebook will cover the ML model construction and testing.

# %% [markdown]
# Import the required packages:

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %% [markdown]
# We load the complete feature set as well as the original metadata:

# %%
metadata_df = pd.read_csv('large_data/UrbanSound8K/metadata/UrbanSound8K.csv')

features_df = pd.read_csv('large_data/extracted_features.csv', index_col=0)
features_df.info()
features_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8732 entries, 0 to 8731
# Columns: 404 entries, eq_0 to hits_ratio
# dtypes: float64(403), int64(1)
# memory usage: 27.0 MB
#        eq_0     eq_10     eq_20     eq_30     eq_40     eq_60     eq_80  \
# 0 -1.375995 -1.494469 -1.451719 -1.281426 -0.658946 -0.689535 -0.606677
# 1  0.856480  0.821880  0.997462  0.783837  0.912475  0.721754  0.758189
# 2  0.819386  0.792283  0.720321  0.789714  0.724272  0.727021  0.766071
# 3  0.772997  0.642017  0.714451  0.829689  0.603400  0.852557  0.792330
# 4  0.931373  0.637854  0.799281  1.071200  0.785805  0.841281  0.746758
#
#      eq_120    eq_160    eq_230  ...  range_high.f0_stats.f0_min  \
# 0 -0.516618 -0.041881 -0.349792  ...                  544.841599
# 1  0.456822  0.275369  0.209168  ...                 2080.949703
# 2  0.408717  0.278678  0.179953  ...                 1077.167118
# 3  0.878636  0.348520  0.328973  ...                  523.251131
# 4  0.589374  0.427006  0.312896  ...                 2057.047957
#
#    range_high.f0_signal  range_low.f0_stats.f0_mean  \
# 0              0.571429                         NaN
# 1              0.109827                         NaN
# 2              0.294798                 1128.712229
# 3              0.260116                         NaN
# 4              0.156069                   66.850514
#
#    range_low.f0_stats.f0_median  range_low.f0_stats.f0_std  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                   1115.153334                  36.960305
# 3                           NaN                        NaN
# 4                     65.785287                   1.875716
#
#    range_low.f0_stats.f0_iqr  range_low.f0_stats.f0_max  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                  57.225801                1195.191751
# 3                        NaN                        NaN
# 4                   1.731598                  70.915367
#
#    range_low.f0_stats.f0_min  power_ratio  hits_ratio
# 0                        NaN     2.725290   -1.055247
# 1                        NaN     0.553428   -3.301030
# 2                1077.167118    -1.699984   -1.630523
# 3                        NaN     0.889862   -1.567587
# 4                  65.406391    -1.688568   -3.301030
#
# [5 rows x 404 columns]

# %% [markdown]
# We can list the feature names/keys to see what is available:

# %%
feature_keys = list(features_df)
for k in feature_keys:
    print(k)
# Out:
# eq_0
# eq_10
# eq_20
# eq_30
# eq_40
# eq_60
# eq_80
# eq_120
# eq_160
# eq_230
# eq_300
# eq_450
# eq_600
# eq_900
# eq_1200
# eq_1800
# eq_2400
# eq_3700
# eq_5000
# eq_7500
# eq_10000
# eq_15000
# eq_20000
# crestfactor
# harmonic_power
# percussive_power
# harmonic_hits
# percussive_hits
# roll_32.y_mw_zcr
# roll_32.y_mw_power_mcr
# roll_32.spec_flatness.mean
# roll_32.spec_flatness.median
# roll_32.spec_flatness.std
# roll_32.spec_flatness.iqr
# roll_32.spec_flatness.max
# roll_32.spec_flatness.min
# roll_32.spec_flatness_mw.mean
# roll_32.spec_flatness_mw.median
# roll_32.spec_flatness_mw.std
# roll_32.spec_flatness_mw.iqr
# roll_32.spec_flatness_mw.max
# roll_32.spec_flatness_mw.min
# roll_32.spec_centroid.mean
# roll_32.spec_centroid.median
# roll_32.spec_centroid.std
# roll_32.spec_centroid.iqr
# roll_32.spec_centroid.max
# roll_32.spec_centroid.min
# roll_32.spec_centroid_mw.mean
# roll_32.spec_centroid_mw.median
# roll_32.spec_centroid_mw.std
# roll_32.spec_centroid_mw.iqr
# roll_32.spec_centroid_mw.max
# roll_32.spec_centroid_mw.min
# roll_32.spec_bandwidth.mean
# roll_32.spec_bandwidth.median
# roll_32.spec_bandwidth.std
# roll_32.spec_bandwidth.iqr
# roll_32.spec_bandwidth.max
# roll_32.spec_bandwidth.min
# roll_32.spec_bandwidth_mw.mean
# roll_32.spec_bandwidth_mw.median
# roll_32.spec_bandwidth_mw.std
# roll_32.spec_bandwidth_mw.iqr
# roll_32.spec_bandwidth_mw.max
# roll_32.spec_bandwidth_mw.min
# roll_32.spec_rolloff.mean
# roll_32.spec_rolloff.median
# roll_32.spec_rolloff.std
# roll_32.spec_rolloff.iqr
# roll_32.spec_rolloff.max
# roll_32.spec_rolloff.min
# roll_32.spec_rolloff_mw.mean
# roll_32.spec_rolloff_mw.median
# roll_32.spec_rolloff_mw.std
# roll_32.spec_rolloff_mw.iqr
# roll_32.spec_rolloff_mw.max
# roll_32.spec_rolloff_mw.min
# roll_32.bands_mw_5.0
# roll_32.bands_mw_5.1
# roll_32.bands_mw_5.2
# roll_32.bands_mw_5.3
# roll_32.bands_mw_5.4
# roll_32.bands_mw_10.0
# roll_32.bands_mw_10.1
# roll_32.bands_mw_10.2
# roll_32.bands_mw_10.3
# roll_32.bands_mw_10.4
# roll_32.bands_mw_10.5
# roll_32.bands_mw_10.6
# roll_32.bands_mw_10.7
# roll_32.bands_mw_10.8
# roll_32.bands_mw_10.9
# roll_32.bands_mw_20.0
# roll_32.bands_mw_20.1
# roll_32.bands_mw_20.2
# roll_32.bands_mw_20.3
# roll_32.bands_mw_20.4
# roll_32.bands_mw_20.5
# roll_32.bands_mw_20.6
# roll_32.bands_mw_20.7
# roll_32.bands_mw_20.8
# roll_32.bands_mw_20.9
# roll_32.bands_mw_20.10
# roll_32.bands_mw_20.11
# roll_32.bands_mw_20.12
# roll_32.bands_mw_20.13
# roll_32.bands_mw_20.14
# roll_32.bands_mw_20.15
# roll_32.bands_mw_20.16
# roll_32.bands_mw_20.17
# roll_32.bands_mw_20.18
# roll_32.bands_mw_20.19
# roll_32.logbands_mw_5.0
# roll_32.logbands_mw_5.1
# roll_32.logbands_mw_5.2
# roll_32.logbands_mw_5.3
# roll_32.logbands_mw_5.4
# roll_32.logbands_mw_10.0
# roll_32.logbands_mw_10.1
# roll_32.logbands_mw_10.2
# roll_32.logbands_mw_10.3
# roll_32.logbands_mw_10.4
# roll_32.logbands_mw_10.5
# roll_32.logbands_mw_10.6
# roll_32.logbands_mw_10.7
# roll_32.logbands_mw_10.8
# roll_32.logbands_mw_10.9
# roll_32.logbands_mw_20.0
# roll_32.logbands_mw_20.1
# roll_32.logbands_mw_20.2
# roll_32.logbands_mw_20.3
# roll_32.logbands_mw_20.4
# roll_32.logbands_mw_20.5
# roll_32.logbands_mw_20.6
# roll_32.logbands_mw_20.7
# roll_32.logbands_mw_20.8
# roll_32.logbands_mw_20.9
# roll_32.logbands_mw_20.10
# roll_32.logbands_mw_20.11
# roll_32.logbands_mw_20.12
# roll_32.logbands_mw_20.13
# roll_32.logbands_mw_20.14
# roll_32.logbands_mw_20.15
# roll_32.logbands_mw_20.16
# roll_32.logbands_mw_20.17
# roll_32.logbands_mw_20.18
# roll_32.logbands_mw_20.19
# roll_64.y_mw_zcr
# roll_64.y_mw_power_mcr
# roll_64.spec_flatness.mean
# roll_64.spec_flatness.median
# roll_64.spec_flatness.std
# roll_64.spec_flatness.iqr
# roll_64.spec_flatness.max
# roll_64.spec_flatness.min
# roll_64.spec_flatness_mw.mean
# roll_64.spec_flatness_mw.median
# roll_64.spec_flatness_mw.std
# roll_64.spec_flatness_mw.iqr
# roll_64.spec_flatness_mw.max
# roll_64.spec_flatness_mw.min
# roll_64.spec_centroid.mean
# roll_64.spec_centroid.median
# roll_64.spec_centroid.std
# roll_64.spec_centroid.iqr
# roll_64.spec_centroid.max
# roll_64.spec_centroid.min
# roll_64.spec_centroid_mw.mean
# roll_64.spec_centroid_mw.median
# roll_64.spec_centroid_mw.std
# roll_64.spec_centroid_mw.iqr
# roll_64.spec_centroid_mw.max
# roll_64.spec_centroid_mw.min
# roll_64.spec_bandwidth.mean
# roll_64.spec_bandwidth.median
# roll_64.spec_bandwidth.std
# roll_64.spec_bandwidth.iqr
# roll_64.spec_bandwidth.max
# roll_64.spec_bandwidth.min
# roll_64.spec_bandwidth_mw.mean
# roll_64.spec_bandwidth_mw.median
# roll_64.spec_bandwidth_mw.std
# roll_64.spec_bandwidth_mw.iqr
# roll_64.spec_bandwidth_mw.max
# roll_64.spec_bandwidth_mw.min
# roll_64.spec_rolloff.mean
# roll_64.spec_rolloff.median
# roll_64.spec_rolloff.std
# roll_64.spec_rolloff.iqr
# roll_64.spec_rolloff.max
# roll_64.spec_rolloff.min
# roll_64.spec_rolloff_mw.mean
# roll_64.spec_rolloff_mw.median
# roll_64.spec_rolloff_mw.std
# roll_64.spec_rolloff_mw.iqr
# roll_64.spec_rolloff_mw.max
# roll_64.spec_rolloff_mw.min
# roll_64.bands_mw_5.0
# roll_64.bands_mw_5.1
# roll_64.bands_mw_5.2
# roll_64.bands_mw_5.3
# roll_64.bands_mw_5.4
# roll_64.bands_mw_10.0
# roll_64.bands_mw_10.1
# roll_64.bands_mw_10.2
# roll_64.bands_mw_10.3
# roll_64.bands_mw_10.4
# roll_64.bands_mw_10.5
# roll_64.bands_mw_10.6
# roll_64.bands_mw_10.7
# roll_64.bands_mw_10.8
# roll_64.bands_mw_10.9
# roll_64.bands_mw_20.0
# roll_64.bands_mw_20.1
# roll_64.bands_mw_20.2
# roll_64.bands_mw_20.3
# roll_64.bands_mw_20.4
# roll_64.bands_mw_20.5
# roll_64.bands_mw_20.6
# roll_64.bands_mw_20.7
# roll_64.bands_mw_20.8
# roll_64.bands_mw_20.9
# roll_64.bands_mw_20.10
# roll_64.bands_mw_20.11
# roll_64.bands_mw_20.12
# roll_64.bands_mw_20.13
# roll_64.bands_mw_20.14
# roll_64.bands_mw_20.15
# roll_64.bands_mw_20.16
# roll_64.bands_mw_20.17
# roll_64.bands_mw_20.18
# roll_64.bands_mw_20.19
# roll_64.logbands_mw_5.0
# roll_64.logbands_mw_5.1
# roll_64.logbands_mw_5.2
# roll_64.logbands_mw_5.3
# roll_64.logbands_mw_5.4
# roll_64.logbands_mw_10.0
# roll_64.logbands_mw_10.1
# roll_64.logbands_mw_10.2
# roll_64.logbands_mw_10.3
# roll_64.logbands_mw_10.4
# roll_64.logbands_mw_10.5
# roll_64.logbands_mw_10.6
# roll_64.logbands_mw_10.7
# roll_64.logbands_mw_10.8
# roll_64.logbands_mw_10.9
# roll_64.logbands_mw_20.0
# roll_64.logbands_mw_20.1
# roll_64.logbands_mw_20.2
# roll_64.logbands_mw_20.3
# roll_64.logbands_mw_20.4
# roll_64.logbands_mw_20.5
# roll_64.logbands_mw_20.6
# roll_64.logbands_mw_20.7
# roll_64.logbands_mw_20.8
# roll_64.logbands_mw_20.9
# roll_64.logbands_mw_20.10
# roll_64.logbands_mw_20.11
# roll_64.logbands_mw_20.12
# roll_64.logbands_mw_20.13
# roll_64.logbands_mw_20.14
# roll_64.logbands_mw_20.15
# roll_64.logbands_mw_20.16
# roll_64.logbands_mw_20.17
# roll_64.logbands_mw_20.18
# roll_64.logbands_mw_20.19
# roll_128.y_mw_zcr
# roll_128.y_mw_power_mcr
# roll_128.spec_flatness.mean
# roll_128.spec_flatness.median
# roll_128.spec_flatness.std
# roll_128.spec_flatness.iqr
# roll_128.spec_flatness.max
# roll_128.spec_flatness.min
# roll_128.spec_flatness_mw.mean
# roll_128.spec_flatness_mw.median
# roll_128.spec_flatness_mw.std
# roll_128.spec_flatness_mw.iqr
# roll_128.spec_flatness_mw.max
# roll_128.spec_flatness_mw.min
# roll_128.spec_centroid.mean
# roll_128.spec_centroid.median
# roll_128.spec_centroid.std
# roll_128.spec_centroid.iqr
# roll_128.spec_centroid.max
# roll_128.spec_centroid.min
# roll_128.spec_centroid_mw.mean
# roll_128.spec_centroid_mw.median
# roll_128.spec_centroid_mw.std
# roll_128.spec_centroid_mw.iqr
# roll_128.spec_centroid_mw.max
# roll_128.spec_centroid_mw.min
# roll_128.spec_bandwidth.mean
# roll_128.spec_bandwidth.median
# roll_128.spec_bandwidth.std
# roll_128.spec_bandwidth.iqr
# roll_128.spec_bandwidth.max
# roll_128.spec_bandwidth.min
# roll_128.spec_bandwidth_mw.mean
# roll_128.spec_bandwidth_mw.median
# roll_128.spec_bandwidth_mw.std
# roll_128.spec_bandwidth_mw.iqr
# roll_128.spec_bandwidth_mw.max
# roll_128.spec_bandwidth_mw.min
# roll_128.spec_rolloff.mean
# roll_128.spec_rolloff.median
# roll_128.spec_rolloff.std
# roll_128.spec_rolloff.iqr
# roll_128.spec_rolloff.max
# roll_128.spec_rolloff.min
# roll_128.spec_rolloff_mw.mean
# roll_128.spec_rolloff_mw.median
# roll_128.spec_rolloff_mw.std
# roll_128.spec_rolloff_mw.iqr
# roll_128.spec_rolloff_mw.max
# roll_128.spec_rolloff_mw.min
# roll_128.bands_mw_5.0
# roll_128.bands_mw_5.1
# roll_128.bands_mw_5.2
# roll_128.bands_mw_5.3
# roll_128.bands_mw_5.4
# roll_128.bands_mw_10.0
# roll_128.bands_mw_10.1
# roll_128.bands_mw_10.2
# roll_128.bands_mw_10.3
# roll_128.bands_mw_10.4
# roll_128.bands_mw_10.5
# roll_128.bands_mw_10.6
# roll_128.bands_mw_10.7
# roll_128.bands_mw_10.8
# roll_128.bands_mw_10.9
# roll_128.bands_mw_20.0
# roll_128.bands_mw_20.1
# roll_128.bands_mw_20.2
# roll_128.bands_mw_20.3
# roll_128.bands_mw_20.4
# roll_128.bands_mw_20.5
# roll_128.bands_mw_20.6
# roll_128.bands_mw_20.7
# roll_128.bands_mw_20.8
# roll_128.bands_mw_20.9
# roll_128.bands_mw_20.10
# roll_128.bands_mw_20.11
# roll_128.bands_mw_20.12
# roll_128.bands_mw_20.13
# roll_128.bands_mw_20.14
# roll_128.bands_mw_20.15
# roll_128.bands_mw_20.16
# roll_128.bands_mw_20.17
# roll_128.bands_mw_20.18
# roll_128.bands_mw_20.19
# roll_128.logbands_mw_5.0
# roll_128.logbands_mw_5.1
# roll_128.logbands_mw_5.2
# roll_128.logbands_mw_5.3
# roll_128.logbands_mw_5.4
# roll_128.logbands_mw_10.0
# roll_128.logbands_mw_10.1
# roll_128.logbands_mw_10.2
# roll_128.logbands_mw_10.3
# roll_128.logbands_mw_10.4
# roll_128.logbands_mw_10.5
# roll_128.logbands_mw_10.6
# roll_128.logbands_mw_10.7
# roll_128.logbands_mw_10.8
# roll_128.logbands_mw_10.9
# roll_128.logbands_mw_20.0
# roll_128.logbands_mw_20.1
# roll_128.logbands_mw_20.2
# roll_128.logbands_mw_20.3
# roll_128.logbands_mw_20.4
# roll_128.logbands_mw_20.5
# roll_128.logbands_mw_20.6
# roll_128.logbands_mw_20.7
# roll_128.logbands_mw_20.8
# roll_128.logbands_mw_20.9
# roll_128.logbands_mw_20.10
# roll_128.logbands_mw_20.11
# roll_128.logbands_mw_20.12
# roll_128.logbands_mw_20.13
# roll_128.logbands_mw_20.14
# roll_128.logbands_mw_20.15
# roll_128.logbands_mw_20.16
# roll_128.logbands_mw_20.17
# roll_128.logbands_mw_20.18
# roll_128.logbands_mw_20.19
# range_low.f0_signal
# range_high.f0_stats.f0_mean
# range_high.f0_stats.f0_median
# range_high.f0_stats.f0_std
# range_high.f0_stats.f0_iqr
# range_high.f0_stats.f0_max
# range_high.f0_stats.f0_min
# range_high.f0_signal
# range_low.f0_stats.f0_mean
# range_low.f0_stats.f0_median
# range_low.f0_stats.f0_std
# range_low.f0_stats.f0_iqr
# range_low.f0_stats.f0_max
# range_low.f0_stats.f0_min
# power_ratio
# hits_ratio

# %% [markdown]
# As described in a previous notebook, we know that some of our data is very noisy or incorrectly labeled. As such, we expect some extreme outliers when examining features per class. We thus choose here to use box plots, as they present the outliers separately from the main batch of data for each class.
#
# We define a helper function as all plots will follow the same form:

# %%
meta_and_features = pd.concat([metadata_df, features_df], axis=1)
def feature_boxplot(feature_key, ylim=None):
    seaborn.boxplot(data=meta_and_features, x='class', y=feature_key)
    plt.xticks(rotation=90)
    if ylim is not None:
        plt.ylim(ylim)
    plt.show()

# %% [markdown]
# We're now ready to investigate a few features.

# %% [markdown]
# ## Equalizer bands
#
# The value in each equalizer band corresponds to the audio power in a particular range of frequencies. We plot a low frequency band, middling frequency band, and high frequency band. Gun shots appear to have very high power content in low frequencies. Higher frequencies have a slightly less spread out distribution in classes, but still exhibit some discrimination between certain classes.

# %%
# Low frequency band
feature_boxplot('eq_0')

# %%
# Middling frequency band
feature_boxplot('eq_230')

# %%
# High frequency band
feature_boxplot('eq_5000',[-2.5, 2.5])

# %% [markdown]
# ## Harmonic and Percussive components
#
# Musicality of the samples differentiates between classes in an intuitive manner: car horns have high harmonic power, followed by sirens. Dog barks and gun shots have high percussive power. Engine idling and jackhammers, due to their constant 'beat', register high percussive hits. Unfortunately, it seems street music does not register strongly with these features, possibly due to the noise inherent in their samples.

# %%
# Harmonic power
feature_boxplot('harmonic_power',[0,0.01])

# %%
# Percussive power
feature_boxplot('percussive_power',[0,0.004])

# %%
# Percussive hits
feature_boxplot('percussive_hits',[0,60])

# %% [markdown]
# ## Crestfactor
#
# Crestfactors, as a measure of "suddenness", interesting picks up gun shots, dog barks, and children playing. We believe that is because of the suddenness of children shouts and dog barks causing spikes in the wave form in a manner akin to gun shots.

# %%
feature_boxplot('crestfactor', [0, 30])

# %% [markdown]
# ## Spectral rolloff
#
# A measure of the frequency below which 85% of the power is contained, as a function of time. Here, the median and the IQR (inter-quartile range) pick up different classes: A high median, meaning a consistently high rolloff frequency within the considered window of time, indicates drilling or jackhammering. A high IQR, meaning large variation within the considered window, preferentially indicates gun shots, possibly due to the 'suddenness', akin to the crestfactor feature.

# %%
# Spectral rolloff median
feature_boxplot('roll_64.spec_rolloff_mw.median')

# %%
# Spectral rolloff IQR
feature_boxplot('roll_64.spec_rolloff_mw.iqr',[0,2000])

# %% [markdown]
# ## Zero crossing rate
#
# A high zero crossing rate within a chosen time window seems to indicate drilling or jackhammering, possibly due to the consistency of repetitiveness of those sounds compared to, say, street music playing varying notes.

# %%
feature_boxplot('roll_64.y_mw_zcr',[0,0.5])

# %% [markdown]
# ## Minimal spectral flatness
#
# As a measure of how close to white noise a sound is, the minimal spectral flatness in a considered window seems to be much higher for drilling and jackhammering. As with the zero crossing rate, this might be because of the consistency of the drilling and jackhammering sound, meaning that the minimum picked up flatness remains high in the whole window, unlike briefer sounds.

# %%
feature_boxplot('roll_128.spec_flatness_mw.min', [0,.2])

# %% [markdown]
# ## Fundamental frequency IQR
#
# As police sirens tend to oscillate between two clear tones, the inter-quartile range of the fundamental frequency estimate seems to strongly pick them out from the other classes.

# %%
feature_boxplot('range_high.f0_stats.f0_iqr', [-10, 1000])
